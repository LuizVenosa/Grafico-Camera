# %%
import pandas as pd

votacao = pd.read_csv('votacao_candidato.csv', encoding='latin-1', sep=';')

# %%
votacao_th = votacao.loc[votacao['Número candidato'] == 15123]
votacao_th.sort_values(by='Votos nominais', ascending=False)
# Out:
#                     Cargo                      Município  \
# 86305   Deputado Estadual                 RIO DE JANEIRO
# 29886   Deputado Estadual             SÃO JOÃO DE MERITI
# 86673   Deputado Estadual                DUQUE DE CAXIAS
# 102221  Deputado Estadual                    NOVA IGUAÇU
# 32147   Deputado Estadual           CACHOEIRAS DE MACACU
# ...                   ...                            ...
# 128862  Deputado Estadual                      VARRE-SAI
# 134361  Deputado Estadual                SÃO JOSÉ DE UBÁ
# 139924  Deputado Estadual                        CAMBUCI
# 139317  Deputado Estadual                    PORCIÚNCULA
# 141459  Deputado Estadual  SÃO JOSÉ DO VALE DO RIO PRETO
#
#                          Nome candidato  Número candidato  Código município  \
# 86305   TIEGO RAIMUNDO DOS SANTOS SILVA             15123             60011
# 29886   TIEGO RAIMUNDO DOS SANTOS SILVA             15123             59013
# ...

# %%
votacao = pd.read_csv('votacao_candidato.csv', encoding='latin-1', sep=';')

# %%
votacao.sort_values(by='Votos nominais', ascending=False)
# Out:
#                  Cargo       Município                   Nome candidato  \
# 80   Deputado Estadual  RIO DE JANEIRO  TIEGO RAIMUNDO DOS SANTOS SILVA
# 142  Deputado Estadual  RIO DE JANEIRO  TIEGO RAIMUNDO DOS SANTOS SILVA
# 20   Deputado Estadual  RIO DE JANEIRO  TIEGO RAIMUNDO DOS SANTOS SILVA
# 112  Deputado Estadual  RIO DE JANEIRO  TIEGO RAIMUNDO DOS SANTOS SILVA
# 33   Deputado Estadual  RIO DE JANEIRO  TIEGO RAIMUNDO DOS SANTOS SILVA
# ..                 ...             ...                              ...
# 157  Deputado Estadual       VARRE-SAI  TIEGO RAIMUNDO DOS SANTOS SILVA
# 164  Deputado Estadual      NATIVIDADE  TIEGO RAIMUNDO DOS SANTOS SILVA
# 159  Deputado Estadual           CARMO  TIEGO RAIMUNDO DOS SANTOS SILVA
# 167  Deputado Estadual        CORDEIRO  TIEGO RAIMUNDO DOS SANTOS SILVA
# 179  Deputado Estadual     PORCIÚNCULA  TIEGO RAIMUNDO DOS SANTOS SILVA
#
#      Número candidato  Código município  Zona  Votos nominais  \
# ...
